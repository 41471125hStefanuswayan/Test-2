# %%
import pandas as pd

# %%
file = "StudentsPerformance.csv"
data = pd.read_csv(file)
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # This dataset has 1000 rows and 8 columns.

# %%
data.shape
# Out:
# (1000, 8)

# %% [markdown]
# # Checking for missing values.

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # A. Short sentences addressing the objective(s)

# %% [markdown]
# The primary objective of this Python code is to perform a comprehensive Exploratory Data Analysis (EDA) on a dataset named 'StudentsPerformance.csv'. This is achieved by systematically inspecting, cleaning (if necessary), and visualizing the data to understand its structure, identify patterns, and find relationships between variables.
#
# Dataset: (https://www.kaggle.com/datasets/spscientist/students-performance-in-exams/data)
# The dataset consists of 1000 participants from different backgrounds to understand the influence of the parents background, test preparation, and other factors on participants' performance.

# %% [markdown]
# # B. Pseudocode and/or flowchart

# %%
from IPython.display import Image, display
display(Image(filename='Pseudocode and Flowchart.jpeg'))

# %% [markdown]
# # C. At least one visualization

# %% [raw]
# In order to show a complete diagram of the participants, the pie-charts below can be used to visualize the participant’s background and the factors that can affect their performance in doing the tests.

# %% [raw]
# https://docs.google.com/spreadsheets/d/1IGsAWODgTw1lBE9c63HtlZDfDL1UJQrxIVHa3X9N_DE/edit?gid=1810011631#gid=1810011631

# %%
from IPython.display import Image, display
display(Image(filename='Piechart.jpeg'))

# %% [raw]
# On the other hand, the bar-charts below can be used to visualize the average score of each test related to the factors that can affect the participant's performance. Here we make a comparison based on the participant's parental level of education, lunch, and test preparation.

# %%
from IPython.display import Image, display
display(Image(filename='Barchart.jpeg'))

# %% [raw]
# By looking at these diagrams, we can conclude that this dataset suggests that preparatory and socioeconomic factors have the strongest correlation with academic achievement.
# Parental Education: Higher average test scores in all subjects are generally linked to higher parental education levels.
# Lunch Program: Participants on the free/reduced program performed worse than those who paid for a standard lunch, which may indicate a higher socioeconomic status.
# Test Preparation: After completing a test preparation course, average scores for all three subjects increased noticeably and significantly.
# These results suggest that, in addition to innate ability, socioeconomic background, as indicated by parental education and lunch status, and access to preparation materials may have a substantial impact on a participant's performance on these tests.
